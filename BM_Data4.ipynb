# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot

BM_Data=pd.read_csv("E:/Hadoop Softwares/Skillathon/Assigments/pandas dataset/BM_data.csv")

# %%
BM_Data.shape
# Out:
# (8523, 12)

# %%
BM_Data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
BM_Data.isna().count()
# Out:
# Item_Identifier              8523
# Item_Weight                  8523
# Item_Fat_Content             8523
# Item_Visibility              8523
# Item_Type                    8523
# Item_MRP                     8523
# Outlet_Identifier            8523
# Outlet_Establishment_Year    8523
# Outlet_Size                  8523
# Outlet_Location_Type         8523
# Outlet_Type                  8523
# Item_Outlet_Sales            8523
# dtype: int64

# %%
BM_Data.isnull().count()
# Out:
# Item_Identifier              8523
# Item_Weight                  8523
# Item_Fat_Content             8523
# Item_Visibility              8523
# Item_Type                    8523
# Item_MRP                     8523
# Outlet_Identifier            8523
# Outlet_Establishment_Year    8523
# Outlet_Size                  8523
# Outlet_Location_Type         8523
# Outlet_Type                  8523
# Item_Outlet_Sales            8523
# dtype: int64

# %%
BM_Data.Outlet_Size.isnull().count()
# Out:
# 8523

# %%
BM_Data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
BM_Data.Item_Weight.isna().sum()
# Out:
# 1463

# %%
BM_Data.Outlet_Size.fillna(value="Medium", inplace=True)

# %%
BM_Data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
BM_Data.Item_Weight.isna().sum()
# Out:
# 1463

# %%
BM_Data.dropna(axis=0, inplace=True)

# %%
BM_Data.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
BM_Data.Item_MRP.describe()
# Out:
# count    7060.000000
# mean      141.240683
# std        62.411888
# min        31.490000
# 25%        94.143600
# 50%       142.729900
# 75%       186.024000
# max       266.888400
# Name: Item_MRP, dtype: float64

# %%
#As we have only two categories in Item_Fat_Content i.e Low Fat and Regular but, its categorized into different values. Merged all values with rplacing string

BM_Data['Item_Fat_Content'] = BM_Data['Item_Fat_Content'].replace(['LF', 'low fat'],'Low Fat')

BM_Data['Item_Fat_Content'] = BM_Data['Item_Fat_Content'].replace(['reg'],'Regular')

# %%
BM_Data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
BM_Data['Item_Fat_Content'] = BM_Data['Item_Fat_Content'].replace(['LF', 'low fat'],'Low Fat')

BM_Data['Item_Fat_Content'] = BM_Data['Item_Fat_Content'].replace(['reg'],'Regular')

# %%
sb.catplot(x ='Outlet_Establishment_Year', hue ='Item_Fat_Content',  
kind ='count', data = BM_Data)

# %%
sb.catplot(x ='Item_Fat_Content', hue ='Item_Type',  
kind ='count', data = BM_Data)

# %%
sb.catplot(x ='Outlet_Establishment_Year', hue ='Item_Type',  
kind ='count', data = BM_Data)

# %%
sb.pairplot(data=BM_Data, hue='Outlet_Establishment_Year')
# Out:
# C:\Users\LENOVO PC\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\LENOVO PC\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
