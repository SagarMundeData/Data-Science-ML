# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
wine_df=pd.read_csv("E:/Hadoop Softwares/Skillathon/Assigments/pandas dataset/wine_dataUC.csv")

# %%
wine_df.head
# Out:
# <bound method NDFrame.head of      Class  alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  \
# 0        1    13.20        1.78  2.14               11.2      100.0
# 1        1    13.16        2.36  2.67               18.6      101.0
# 2        1    14.37        1.95  2.50               16.8      113.0
# 3        1    13.24        2.59  2.87               21.0      118.0
# 4        1    14.20        1.76  2.45               15.2      112.0
# ..     ...      ...         ...   ...                ...        ...
# 172      3    13.71        5.65  2.45               20.5       95.0
# 173      3    13.40        3.91  2.48               23.0      102.0
# 174      3    13.27        4.28  2.26               20.0      120.0
# 175      3    13.17        2.59  2.37               20.0      120.0
# 176      3    14.13        4.10  2.74               24.5       96.0
#
#      total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# ...

# %%
wine_df.columns.summary
# Out:
# <bound method Index.summary of Index(['Class', 'alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash',
#        'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
#        'proanthocyanins', 'color_intensity', 'hue', 'od315_of_diluted_wines',
#        'proline'],
#       dtype='object')>

# %%
wine_df_orignal=wine_df.copy()

# %%
#allocating columns as per given names


wine_df.columns = ['Class','alcohol','malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols','proanthocyanins','color_intensity','hue', 'od315_of_diluted_wines', 'proline']

# %%
wine_df.head()
# Out:
#    Class  alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  \
# 0      1    13.20        1.78  2.14               11.2      100.0
# 1      1    13.16        2.36  2.67               18.6      101.0
# 2      1    14.37        1.95  2.50               16.8      113.0
# 3      1    13.24        2.59  2.87               21.0      118.0
# 4      1    14.20        1.76  2.45               15.2      112.0
#
#    total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0           2.65        2.76                  0.26             1.28
# 1           2.80        3.24                  0.30             2.81
# 2           3.85        3.49                  0.24             2.18
# 3           2.80        2.69                  0.39             1.82
# 4           3.27        3.39                  0.34             1.97
#
#    color_intensity   hue  od315_of_diluted_wines  proline
# 0             4.38  1.05                    3.40   1050.0
# ...

# %%
wine_df.columns
# Out:
# Index(['Class', 'alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash',
#        'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
#        'proanthocyanins', 'color_intensity', 'hue', 'od315_of_diluted_wines',
#        'proline'],
#       dtype='object')

# %%
wine_df['Class'].value_counts(normalize=True).plot.bar(title= 'Credit_History')

# %%
wine_df['alcohol'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      13.20
# 1      13.16
# 2      14.37
# 3      13.24
# 4      14.20
#        ...
# 172    13.71
# 173    13.40
# 174    13.27
# 175    13.17
# 176    14.13
# Name: alcohol, Length: 177, dtype: float64>

# %%
#Found some raw data converting it to nan for further processing

wine_df = wine_df.replace([['lost','missing']],'nan')

# %%
wine_df.tail(50)
# Out:
#      Class  alcohol  malic_acid   ash  alcalinity_of_ash   magnesium  \
# 127      2    12.37        1.63  2.30          24.500000   88.000000
# 128      2    12.04        4.30  2.38          22.000000   80.000000
# 129      3    12.86        1.35  2.32          18.000000  122.000000
# 130      3    12.88        2.99  2.40          20.000000  104.000000
# 131      3    12.81        2.31  2.40          24.000000   99.614943
# 132      3    12.70        3.55  2.36          21.500000  106.000000
# 133      3    12.51        1.24  2.25          17.500000   85.000000
# 134      3    12.60        2.46  2.20          18.500000   94.000000
# 135      3    12.25        4.72  2.54          21.000000   89.000000
# 136      3    12.53        5.51  2.64          25.000000   96.000000
# 137      3    13.49        3.59  2.19          19.523121   88.000000
# 138      3    12.84        2.96  2.61          24.000000  101.000000
# 139      3    12.93        2.81  2.70          21.000000   96.000000
# ...

# %%
wine_df.head(50)
# Out:
#     Class  alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  \
# 0       1    13.20        1.78  2.14               11.2      100.0
# 1       1    13.16        2.36  2.67               18.6      101.0
# 2       1    14.37        1.95  2.50               16.8      113.0
# 3       1    13.24        2.59  2.87               21.0      118.0
# 4       1    14.20        1.76  2.45               15.2      112.0
# 5       1    14.39        1.87  2.45               14.6       96.0
# 6       1    14.06        2.15  2.61               17.6      121.0
# 7       1    14.83        1.64  2.17               14.0       97.0
# 8       1    13.86        1.35  2.27               16.0       98.0
# 9       1    14.10        2.16  2.30               18.0      105.0
# 10      1    14.12        1.48  2.32               16.8       95.0
# 11      1    13.75        1.73  2.41               16.0       89.0
# 12      1    14.75        1.73  2.39               11.4       91.0
# ...

# %%
wine_df.isna().sum()
# Out:
# Class                     0
# alcohol                   0
# malic_acid                0
# ash                       0
# alcalinity_of_ash         0
# magnesium                 0
# total_phenols             0
# flavanoids                0
# nonflavanoid_phenols      0
# proanthocyanins           0
# color_intensity           3
# hue                       0
# od315_of_diluted_wines    0
# proline                   0
# dtype: int64

# %%
wine_df['alcalinity_of_ash'].fillna(wine_df['alcalinity_of_ash'].mean(), inplace=True)

# %%
wine_df.alcalinity_of_ash.mean()
# Out:
# 19.523121387283233

# %%
wine_df['magnesium'].fillna(wine_df['magnesium'].mean(), inplace=True)

# %%
wine_df.isna().sum()
# Out:
# Class                     0
# alcohol                   0
# malic_acid                0
# ash                       0
# alcalinity_of_ash         0
# magnesium                 0
# total_phenols             0
# flavanoids                0
# nonflavanoid_phenols      0
# proanthocyanins           0
# color_intensity           3
# hue                       0
# od315_of_diluted_wines    0
# proline                   0
# dtype: int64

# %%
wine_df.isnull().sum()
# Out:
# Class                     0
# alcohol                   0
# malic_acid                0
# ash                       0
# alcalinity_of_ash         0
# magnesium                 0
# total_phenols             0
# flavanoids                0
# nonflavanoid_phenols      0
# proanthocyanins           0
# color_intensity           3
# hue                       0
# od315_of_diluted_wines    0
# proline                   0
# dtype: int64

# %%
wine_df.describe()
# Out:
#             Class     alcohol  malic_acid         ash  alcalinity_of_ash  \
# count  177.000000  177.000000  177.000000  177.000000         177.000000
# mean     1.943503   12.993672    2.339887    2.366158          19.523121
# std      0.773991    0.808808    1.119314    0.275080           3.335610
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.360000    1.600000    2.210000          17.200000
# 50%      2.000000   13.050000    1.870000    2.360000          19.500000
# 75%      3.000000   13.670000    3.100000    2.560000          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         magnesium  total_phenols  flavanoids  nonflavanoid_phenols  \
# count  177.000000     177.000000  177.000000            177.000000
# mean    99.614943       2.292260    2.023446              0.362316
# std     14.172477       0.626465    0.998658              0.124653
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
def countplots(wine_df):
    wine_df["Class"] = pd.Categorical(wine_df["Class"])
    sb.countplot(x="Class", data=wine_df)
    plt.xlabel("Class of wine (1-3 scale)")
    plt.show()
countplots(wine_df)

# %%
df=print(wine_df.groupby("Class").size()*100 / len(wine_df))
# Out:
# Class
# 1    32.768362
# 2    40.112994
# 3    27.118644
# dtype: float64

# %%
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 14 columns):
# Class                     177 non-null category
# alcohol                   177 non-null float64
# malic_acid                177 non-null float64
# ash                       177 non-null float64
# alcalinity_of_ash         177 non-null float64
# magnesium                 177 non-null float64
# total_phenols             177 non-null float64
# flavanoids                177 non-null float64
# nonflavanoid_phenols      177 non-null float64
# proanthocyanins           177 non-null float64
# color_intensity           174 non-null float64
# hue                       177 non-null float64
# od315_of_diluted_wines    177 non-null float64
# proline                   177 non-null float64
# dtypes: category(1), float64(13)
# memory usage: 18.4 KB

# %%
wine_df['color_intensity']=wine_df['color_intensity'].astype(dtype='float64',copy=True)

# %%
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 14 columns):
# Class                     177 non-null category
# alcohol                   177 non-null float64
# malic_acid                177 non-null float64
# ash                       177 non-null float64
# alcalinity_of_ash         177 non-null float64
# magnesium                 177 non-null float64
# total_phenols             177 non-null float64
# flavanoids                177 non-null float64
# nonflavanoid_phenols      177 non-null float64
# proanthocyanins           177 non-null float64
# color_intensity           174 non-null float64
# hue                       177 non-null float64
# od315_of_diluted_wines    177 non-null float64
# proline                   177 non-null float64
# dtypes: category(1), float64(13)
# memory usage: 18.4 KB

# %%
wine_df['proline']=wine_df['proline'].astype(dtype='float64',copy=True)

# %%
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 14 columns):
# Class                     177 non-null category
# alcohol                   177 non-null float64
# malic_acid                177 non-null float64
# ash                       177 non-null float64
# alcalinity_of_ash         177 non-null float64
# magnesium                 177 non-null float64
# total_phenols             177 non-null float64
# flavanoids                177 non-null float64
# nonflavanoid_phenols      177 non-null float64
# proanthocyanins           177 non-null float64
# color_intensity           174 non-null float64
# hue                       177 non-null float64
# od315_of_diluted_wines    177 non-null float64
# proline                   177 non-null float64
# dtypes: category(1), float64(13)
# memory usage: 18.4 KB

# %%
def factorplots(wine_df):
    sb.factorplot(x="Class", y="alcohol", data=wine_df, kind="strip")
    plt.xlabel("Quality level of wine, 1-3 scale")
    plt.ylabel("Alcohol level in wine")
    plt.show()
factorplots(wine_df)
# Out:
# C:\Users\LENOVO PC\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
def factorplots(wine_df):
    sb.factorplot(x="Class", y="malic_acid", data=wine_df, kind="strip")
    plt.xlabel("Quality level of wine, 1-3 scale")
    plt.ylabel("malic acid level in wine")
    plt.show()
factorplots(wine_df)

# %%
def factorplots(wine_df):
    sb.factorplot(x="Class", y="total_phenols", data=wine_df, kind="strip")
    plt.xlabel("Quality level of wine, 1-3 scale")
    plt.ylabel("Phenols in wine")
    plt.show()
factorplots(wine_df)

# %%
sb.boxplot(x= 'Class' , y='alcohol', data=wine_df)

# %%
for i in wine_df.columns:
    sb.boxplot(data= wine_df[i])
    plt.title(i)
    plt.show()

# %%
for i in wine_df.columns:
    sb.distplot(wine_df[i])
    plt.title(i)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-218-713265a5786d> in <module>
#       1 for i in wine_df.columns:
# ----> 2     sb.distplot(wine_df[i])
#       3     plt.title(i)
#       4     plt.show()
#
# ~\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     213     if hist:
#     214         if bins is None:
# --> 215             bins = min(_freedman_diaconis_bins(a), 50)
#     216         hist_kws.setdefault("alpha", 0.4)
#     217         if LooseVersion(mpl.__version__) < LooseVersion("2.2"):
#
# ~\Anaconda3\lib\site-packages\seaborn\distributions.py in _freedman_diaconis_bins(a)
#      37         return int(np.sqrt(a.size))
#      38     else:
# ---> 39         return int(np.ceil((a.max() - a.min()) / h))
#      40
# ...

# %%
wine_df.head()
# Out:
#   Class  alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  \
# 0     1    13.20        1.78  2.14               11.2      100.0
# 1     1    13.16        2.36  2.67               18.6      101.0
# 2     1    14.37        1.95  2.50               16.8      113.0
# 3     1    13.24        2.59  2.87               21.0      118.0
# 4     1    14.20        1.76  2.45               15.2      112.0
#
#    total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0           2.65        2.76                  0.26             1.28
# 1           2.80        3.24                  0.30             2.81
# 2           3.85        3.49                  0.24             2.18
# 3           2.80        2.69                  0.39             1.82
# 4           3.27        3.39                  0.34             1.97
#
#    color_intensity   hue  od315_of_diluted_wines  proline
# 0             4.38  1.05                    3.40   1050.0
# ...

# %%
wine_df['color_intensity'].dtypes
# Out:
# dtype('float64')

# %%
wine_df['color_intensity']=wine_df['color_intensity'].astype(dtype='float64',copy=True)

# %%
wine_df['color_intensity'].isna().sum()
# Out:
# 3

# %%
wine_df['color_intensity'].fillna(wine_df['color_intensity'].mean(),inplace=True)

# %%
################ Distplot for all columns in Wine dataset to see how data is distributed

# %%
for i in wine_df.columns:
    sb.distplot(wine_df[i])
    plt.title(i)
    plt.show()

# %%
ax,fig = plt.subplots(figsize=(10,8))
data= wine_df.corr()
sb.heatmap(data, annot=True)
plt.show()

# %%
#converting class column from category to int64 for heatmap
wine_df['Class']=wine_df['Class'].astype(dtype='int64',copy=True)

# %%
ax,fig = plt.subplots(figsize=(10,8))
data= wine_df.corr()
sb.heatmap(data, annot=True)
plt.show()

# %%
########### Scatter plots for relation between different columns  ##############

# %%
plt.scatter(wine_df['ash'],wine_df['alcohol'])
plt.xlabel('Ash')
plt.ylabel('Alcohol')
plt.show()

# %%
plt.scatter(wine_df['malic_acid'],wine_df['alcohol'])
plt.xlabel('Malic Acid')
plt.ylabel('Alcohol')
plt.show()

# %%
plt.scatter(wine_df['magnesium'],wine_df['alcohol'])
plt.xlabel('Magnesium Content')
plt.ylabel('Alcohol')
plt.show()

# %%
plt.scatter(wine_df['color_intensity'],wine_df['alcohol'])
plt.xlabel('Intensity of the color')
plt.ylabel('Alcohol')
plt.show()

# %%
plt.bar(wine_df['Class'], wine_df['alcohol'], color = 'maroon', width=0.36)
plt.title('relation of alcohol with Class of wine')
plt.xlabel('Class')
plt.ylabel('alcohol')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
wine_df.dropna(inplace=True)

# %%
wine_df.columns
# Out:
# Index(['Class', 'alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash',
#        'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
#        'proanthocyanins', 'color_intensity', 'hue', 'od315_of_diluted_wines',
#        'proline'],
#       dtype='object')

# %%
###I Included all columns in X and Y all models giving less scores, After that im using here Feature selection
#using heatmap pearson correlation coefficient and selecting only columns with more correlated to class.

# %%
wine_df['Class']=wine_df['Class'].astype(dtype='int64',copy=True)

# %%
cor=wine_df.corr()
print(cor)
# Out:
#                            Class   alcohol  malic_acid       ash  \
# Class                   1.000000 -0.321238    0.436127 -0.048260
# alcohol                -0.321238  1.000000    0.099963  0.210964
# malic_acid              0.436127  0.099963    1.000000  0.164955
# ash                    -0.048260  0.210964    0.164955  1.000000
# alcalinity_of_ash       0.514272 -0.304863    0.284872  0.446714
# magnesium              -0.196314  0.259890   -0.048898  0.287801
# total_phenols          -0.717933  0.284543   -0.333512  0.128176
# flavanoids             -0.846485  0.230133   -0.409324  0.114084
# nonflavanoid_phenols    0.487215 -0.151445    0.291501  0.187354
# proanthocyanins        -0.494887  0.127561   -0.217975  0.008082
# color_intensity         0.268686  0.547826    0.250415  0.258753
# hue                    -0.617690 -0.075375   -0.560854 -0.075181
# od315_of_diluted_wines -0.786428  0.057417   -0.366720  0.001503
# ...

# %%
cor=wine_df.corr()
print(cor)
# Out:
#                            Class   alcohol  malic_acid       ash  \
# Class                   1.000000 -0.321238    0.436127 -0.048260
# alcohol                -0.321238  1.000000    0.099963  0.210964
# malic_acid              0.436127  0.099963    1.000000  0.164955
# ash                    -0.048260  0.210964    0.164955  1.000000
# alcalinity_of_ash       0.514272 -0.304863    0.284872  0.446714
# magnesium              -0.196314  0.259890   -0.048898  0.287801
# total_phenols          -0.717933  0.284543   -0.333512  0.128176
# flavanoids             -0.846485  0.230133   -0.409324  0.114084
# nonflavanoid_phenols    0.487215 -0.151445    0.291501  0.187354
# proanthocyanins        -0.494887  0.127561   -0.217975  0.008082
# color_intensity         0.268686  0.547826    0.250415  0.258753
# hue                    -0.617690 -0.075375   -0.560854 -0.075181
# od315_of_diluted_wines -0.786428  0.057417   -0.366720  0.001503
# ...

# %%
#here im selecting only columns which having p value >0.7 
cor_target=abs(cor['Class']) 
relevant_features=cor_target[cor_target > 0.7]
relevant_features
# Out:
# Class                     1.000000
# total_phenols             0.717933
# flavanoids                0.846485
# od315_of_diluted_wines    0.786428
# Name: Class, dtype: float64

# %%
#X = wine_df.iloc[:, [4,6,7,11,12,13]].values
X = wine_df.iloc[:, [6,7,12]].values

# %%
Y= wine_df['Class']

# %%
X.shape
# Out:
# (177, 3)

# %%
Y.shape
# Out:
# (177,)

# %%
#################### Super Vector Machine ######################

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

# %%
from sklearn.svm import SVC

# %%
clf = SVC()
clf.fit(X_train, Y_train)
pred_clf = clf.predict(X_test)
# Out:
# C:\Users\LENOVO PC\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score

# %%
accuracy_SVM = accuracy_score(Y_test, pred_clf)

# %%
print("SVM Classifiers: " + str(accuracy_SVM * 100))
# Out:
# SVM Classifiers: 86.11111111111111

# %%
print(classification_report(Y_test, pred_clf))
print(confusion_matrix(Y_test, pred_clf))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.82      1.00      0.90        14
#            2       1.00      0.64      0.78        14
#            3       0.80      1.00      0.89         8
#
#     accuracy                           0.86        36
#    macro avg       0.87      0.88      0.86        36
# weighted avg       0.89      0.86      0.85        36
#
# [[14  0  0]
#  [ 3  9  2]
#  [ 0  0  8]]

# %%
cm = confusion_matrix(Y_test, pred_clf)

# %%
sb.heatmap(pd.DataFrame(cm), annot=True)

# %%
#################### Naive Bayes ######################

# %%
from sklearn.naive_bayes import GaussianNB

# %%
NB = GaussianNB()

# %%
NB.fit(X_train, Y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
pred_NaiveBayes = NB.predict(X_test)

# %%
print("Naive Baiyes" , accuracy_score(Y_test, pred_NaiveBayes))
# Out:
# Naive Baiyes 0.8055555555555556

# %%
print(confusion_matrix(Y_test, pred_NaiveBayes))
# Out:
# [[14  0  0]
#  [ 4  8  2]
#  [ 0  1  7]]

# %%
print(classification_report(Y_test, pred_NaiveBayes))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.78      1.00      0.88        14
#            2       0.89      0.57      0.70        14
#            3       0.78      0.88      0.82         8
#
#     accuracy                           0.81        36
#    macro avg       0.81      0.82      0.80        36
# weighted avg       0.82      0.81      0.79        36

# %%
cm = confusion_matrix(Y_test, pred_NaiveBayes)

# %%
sb.heatmap(pd.DataFrame(cm), annot=True)

# %%
mat = confusion_matrix(Y_test, pred_NaiveBayes)
sb.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=True,
cmap="YlGnBu",vmin=3,vmax=8)
plt.xlabel('true values- Naive Bayes')
plt.ylabel('predicted values- Naive Bayes')
plt.show()

# %%
####################Logistic Regression######################

# %%
from sklearn.linear_model import LogisticRegression
logis = LogisticRegression()

# %%
logis.fit(X_train, Y_train)
# Out:
# C:\Users\LENOVO PC\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\LENOVO PC\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
pred_logisticRegr = logis.predict(X_test)

# %%
print("Logistic Regression" , accuracy_score(Y_test, pred_logisticRegr))
# Out:
# Logistic Regression 0.8611111111111112

# %%
print(confusion_matrix(Y_test, pred_logisticRegr))
# Out:
# [[14  0  0]
#  [ 3  9  2]
#  [ 0  0  8]]

# %%
print(classification_report(Y_test, pred_logisticRegr))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.82      1.00      0.90        14
#            2       1.00      0.64      0.78        14
#            3       0.80      1.00      0.89         8
#
#     accuracy                           0.86        36
#    macro avg       0.87      0.88      0.86        36
# weighted avg       0.89      0.86      0.85        36

# %%
cm = confusion_matrix(Y_test, pred_NaiveBayes)

# %%
sb.heatmap(pd.DataFrame(cm), annot=True)

# %%
#Comparison Between logistic regression with SVM and Naive bayes Classifier

# %%
##Logistic Regression ####
print("Logistic Regression")
print("Logistic Regression acuuracy score is" , accuracy_score(Y_test, pred_logisticRegr)*100)
print(classification_report(Y_test, pred_logisticRegr))

print("\n *********************************************************************************")

print("Naive_Bayes")
print("Naive_Bayes acuuracy score is" , accuracy_score(Y_test, pred_NaiveBayes)*100)
print(classification_report(Y_test, pred_NaiveBayes))

print("\n *********************************************************************************")


print("SVM Classifier")
print("SVM Classifier acuuracy score is" , accuracy_score(Y_test, pred_clf)*100)
print(classification_report(Y_test, pred_clf))
# Out:
# Logistic Regression
# Logistic Regression acuuracy score is 86.11111111111111
#               precision    recall  f1-score   support
#
#            1       0.82      1.00      0.90        14
#            2       1.00      0.64      0.78        14
#            3       0.80      1.00      0.89         8
#
#     accuracy                           0.86        36
#    macro avg       0.87      0.88      0.86        36
# weighted avg       0.89      0.86      0.85        36
#
#
#  *********************************************************************************
# Naive_Bayes
# Naive_Bayes acuuracy score is 80.55555555555556
#               precision    recall  f1-score   support
#
#            1       0.78      1.00      0.88        14
#            2       0.89      0.57      0.70        14
#            3       0.78      0.88      0.82         8
#
#     accuracy                           0.81        36
#    macro avg       0.81      0.82      0.80        36
# ...

# %%
print("Conclusion:- Both SVM and Logistic Regression having same accuracy score And Naive Bayes got less score")
# Out:
# Conclusion:- Both SVM and Logistic Regression having same accuracy score And Naive Bayes got less score
