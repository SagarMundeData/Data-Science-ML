# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as mp

df=pd.read_csv("E:/Hadoop Softwares/Skillathon/Assigments/pandas dataset/house_rental_data.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0      Sqft  Floor  TotalFloor  Bedroom Living.Room  Bathroom  \
# 0             1  1177.698      2         7.0        2           2         2
# 1             2  2134.800      5         7.0        4           2         2
# 2             3  1138.560      5         7.0        2           2         1
# 3             4  1458.780      2         7.0        3           2         2
# 4             5   967.776     11        14.0        3           2         2
# ..          ...       ...    ...         ...      ...         ...       ...
# 640         644  1359.156      7        15.0        3           2         2
# 641         645   377.148      4        10.0        1           1         1
# 642         646   740.064     13        14.0        1           1         1
# 643         647  1707.840      3        14.0        3           2         2
# 644         648  1376.946      6         7.0        3           2         1
#
#      Price
# 0    62000
# ...

# %%
df.head(100)
# Out:
#     Unnamed: 0      Sqft  Floor  TotalFloor  Bedroom Living.Room  Bathroom  \
# 0            1  1177.698      2         7.0        2           2         2
# 1            2  2134.800      5         7.0        4           2         2
# 2            3  1138.560      5         7.0        2           2         1
# 3            4  1458.780      2         7.0        3           2         2
# 4            5   967.776     11        14.0        3           2         2
# ..         ...       ...    ...         ...      ...         ...       ...
# 95          96  1771.884      4         7.0        4           2         2
# 96          97  1956.900      6        17.0        4           2         2
# 97          98  1743.420      3         7.0        4           2         2
# 98          99  1707.840     13        20.0        2           2         2
# 99         100  2063.640      5         7.0        4           2         2
#
#     Price
# 0   62000
# 1   78000
# 2   58000
# 3   45000
# ...

# %%
df.shape
# Out:
# (645, 8)

# %%
df.isna().sum()
# Out:
# Unnamed: 0     0
# Sqft           0
# Floor          0
# TotalFloor     6
# Bedroom        0
# Living.Room    0
# Bathroom       0
# Price          0
# dtype: int64

# %%
df.dropna()
# Out:
#      Unnamed: 0      Sqft  Floor  TotalFloor  Bedroom Living.Room  Bathroom  \
# 0             1  1177.698      2         7.0        2           2         2
# 1             2  2134.800      5         7.0        4           2         2
# 2             3  1138.560      5         7.0        2           2         1
# 3             4  1458.780      2         7.0        3           2         2
# 4             5   967.776     11        14.0        3           2         2
# ..          ...       ...    ...         ...      ...         ...       ...
# 640         644  1359.156      7        15.0        3           2         2
# 641         645   377.148      4        10.0        1           1         1
# 642         646   740.064     13        14.0        1           1         1
# 643         647  1707.840      3        14.0        3           2         2
# 644         648  1376.946      6         7.0        3           2         1
#
#      Price
# 0    62000
# 1    78000
# 2    58000
# ...

# %%
df.head()
# Out:
#    Unnamed: 0      Sqft  Floor  TotalFloor  Bedroom Living.Room  Bathroom  \
# 0           1  1177.698      2         7.0        2           2         2
# 1           2  2134.800      5         7.0        4           2         2
# 2           3  1138.560      5         7.0        2           2         1
# 3           4  1458.780      2         7.0        3           2         2
# 4           5   967.776     11        14.0        3           2         2
#
#    Price
# 0  62000
# 1  78000
# 2  58000
# 3  45000
# 4  45000

# %%
df.describe()
# Out:
#        Unnamed: 0         Sqft       Floor  TotalFloor     Bedroom  \
# count  645.000000   645.000000  645.000000  639.000000  645.000000
# mean   325.159690  1527.656260    5.939535   10.892019    2.837209
# std    187.312152   767.386531    3.884721    5.005569    1.010740
# min      1.000000   359.358000    1.000000    1.000000    1.000000
# 25%    164.000000   925.080000    3.000000    7.000000    2.000000
# 50%    326.000000  1423.200000    5.000000   12.000000    3.000000
# 75%    487.000000  1892.856000    8.000000   14.000000    4.000000
# max    648.000000  5856.468000   22.000000   38.000000    7.000000
#
#          Bathroom          Price
# count  645.000000     645.000000
# mean     1.810853   61986.823256
# std      0.683574   35635.091007
# min      0.000000    6100.000000
# 25%      1.000000   39000.000000
# 50%      2.000000   50000.000000
# 75%      2.000000   75000.000000
# max      5.000000  250000.000000

# %%
df.head(100)
# Out:
#     Unnamed: 0      Sqft  Floor  TotalFloor  Bedroom Living.Room  Bathroom  \
# 0            1  1177.698      2         7.0        2           2         2
# 1            2  2134.800      5         7.0        4           2         2
# 2            3  1138.560      5         7.0        2           2         1
# 3            4  1458.780      2         7.0        3           2         2
# 4            5   967.776     11        14.0        3           2         2
# ..         ...       ...    ...         ...      ...         ...       ...
# 95          96  1771.884      4         7.0        4           2         2
# 96          97  1956.900      6        17.0        4           2         2
# 97          98  1743.420      3         7.0        4           2         2
# 98          99  1707.840     13        20.0        2           2         2
# 99         100  2063.640      5         7.0        4           2         2
#
#     Price
# 0   62000
# 1   78000
# 2   58000
# 3   45000
# ...

# %%
df.count()
# Out:
# Unnamed: 0     645
# Sqft           645
# Floor          645
# TotalFloor     639
# Bedroom        645
# Living.Room    645
# Bathroom       645
# Price          645
# dtype: int64

# %%
df['TotalFloor'].count()
# Out:
# 639

# %%
#To check the graphical relationsship between all columns
sb.pairplot(data=df)
# Out:
# C:\Users\LENOVO PC\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\LENOVO PC\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
#Plotting data in matrics format
sb.heatmap(df.corr(), annot=True)

# %%
sb.barplot(x="Living.Room", y="Bedroom", data=df)

# %%
#Column Living.room have some string data i.e "Zero" cahnging it to the numbers "0"
df["Living.Room"].replace("zero", 0, inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0      Sqft  Floor  TotalFloor  Bedroom Living.Room  Bathroom  \
# 0           1  1177.698      2         7.0        2           2         2
# 1           2  2134.800      5         7.0        4           2         2
# 2           3  1138.560      5         7.0        2           2         1
# 3           4  1458.780      2         7.0        3           2         2
# 4           5   967.776     11        14.0        3           2         2
#
#    Price
# 0  62000
# 1  78000
# 2  58000
# 3  45000
# 4  45000

# %%
#here we can see that value of Zero is changed to 0.
sb.barplot(x="Living.Room", y="Bedroom", data=df)

# %%
#deleting columns Unnamed
df.drop("Unnamed: 0", axis=1)
# Out:
#          Sqft  Floor  TotalFloor  Bedroom Living.Room  Bathroom  Price
# 0    1177.698      2         7.0        2           2         2  62000
# 1    2134.800      5         7.0        4           2         2  78000
# 2    1138.560      5         7.0        2           2         1  58000
# 3    1458.780      2         7.0        3           2         2  45000
# 4     967.776     11        14.0        3           2         2  45000
# ..        ...    ...         ...      ...         ...       ...    ...
# 640  1359.156      7        15.0        3           2         2  45000
# 641   377.148      4        10.0        1           1         1  24800
# 642   740.064     13        14.0        1           1         1  45000
# 643  1707.840      3        14.0        3           2         2  65000
# 644  1376.946      6         7.0        3           2         1  36000
#
# [645 rows x 7 columns]

# %%
sb.scatterplot(data=df, size=50)

# %%
df.head()
# Out:
#    Unnamed: 0      Sqft  Floor  TotalFloor  Bedroom Living.Room  Bathroom  \
# 0           1  1177.698      2         7.0        2           2         2
# 1           2  2134.800      5         7.0        4           2         2
# 2           3  1138.560      5         7.0        2           2         1
# 3           4  1458.780      2         7.0        3           2         2
# 4           5   967.776     11        14.0        3           2         2
#
#    Price
# 0  62000
# 1  78000
# 2  58000
# 3  45000
# 4  45000

# %%
df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
sb.scatterplot(data=df)

# %%
df.isna()
# Out:
#       Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  Price
# 0    False  False       False    False        False     False  False
# 1    False  False       False    False        False     False  False
# 2    False  False       False    False        False     False  False
# 3    False  False       False    False        False     False  False
# 4    False  False       False    False        False     False  False
# ..     ...    ...         ...      ...          ...       ...    ...
# 640  False  False       False    False        False     False  False
# 641  False  False       False    False        False     False  False
# 642  False  False       False    False        False     False  False
# 643  False  False       False    False        False     False  False
# 644  False  False       False    False        False     False  False
#
# [645 rows x 7 columns]

# %%
#aFTER CLEANING NULL VALUES AND OTHER DATA CHECKING IS THERE ANY ERRORS IN VALUE
df.isnull().sum()
# Out:
# Sqft           0
# Floor          0
# TotalFloor     6
# Bedroom        0
# Living.Room    0
# Bathroom       0
# Price          0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Sqft           0
# Floor          0
# TotalFloor     6
# Bedroom        0
# Living.Room    0
# Bathroom       0
# Price          0
# dtype: int64

# %%
df.dropna(axis=0, inplace=True)

# %% [raw]
# df.isnull().sum()

# %%
sb.barplot(x="Living.Room", y="Bedroom", data=df)

# %%
sb.relplot(x="TotalFloor", y="Bedroom", data=df);

# %%
sb.distplot(df["Price"])

# %%
#finding outliers


sb.scatterplot(x="Price", y="Sqft", data=df)

# %%
#correlation between all indepenedne tvaraible i.e x with price also

sb.heatmap(df.corr())

# %%
mp.figure(figsize = (25,10))
mp.scatter(df["Sqft"], df['Price'], c='black')
mp.xlabel("House by Sqft")
mp.ylabel("Price of house")
mp.show()

# %%
#Allocating data to x and y for train test split
X = df['Sqft'].values.reshape(-1,1)
y = df['Price'].values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=0)

# %%
print(X_train.shape)
# Out:
# (447, 1)

# %%
print(X_test.shape)
# Out:
# (192, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
linearreg = LinearRegression()

# %%
linearreg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
linearreg.intercept_order: {'F'}

# %%
print("y=mx+c where intercept on x and y axis is c is:{} ".format(linearreg.intercept_[0]))
# Out:
# y=mx+c where intercept on x and y axis is c is:4393.3189448920675

# %%
linearreg.coef_order : {'F'}

# %%
print("y=mx+c: co-efficient of value x which is m is:{} ".format(linearreg.coef_[0]))
# Out:
# y=mx+c: co-efficient of value x which is m is:[37.5826751]

# %%
print("The vallue of prediction is: {}".format (X_test))
# Out:
# The vallue of prediction is: [[1366.272]
#  [1885.74 ]
#  [1921.32 ]
#  [1102.98 ]
#  [3255.57 ]
#  [2120.568]
#  [2312.7  ]
#  [2063.64 ]
#  [1732.746]
#  [3735.9  ]
#  [ 700.926]
#  [1163.466]
#  [1487.244]
#  [2067.198]
#  [2846.4  ]
#  [2917.56 ]
#  [ 843.246]
#  [2241.54 ]
#  [1426.758]
#  [ 462.54 ]
#  [1355.598]
#  [ 711.6  ]
#  [ 985.566]
#  [3010.068]
#  [1754.094]
#  [1839.486]
#  [ 996.24 ]
#  [1206.162]
#  [ 711.6  ]
#  [2063.64 ]
#  [1992.48 ]
#  [1124.328]
#  [2768.124]
#  [ 640.44 ]
#  [2134.8  ]
#  [1135.002]
#  [ 718.716]
#  [1565.52 ]
#  [ 914.406]
#  [2063.64 ]
#  [1102.98 ]
#  [1184.814]
#  [3255.57 ]
#  [1391.178]
#  [2700.522]
#  [1401.852]
#  [1387.62 ]
#  [1135.002]
#  [2052.966]
#  [ 964.218]
#  [1099.422]
#  [2191.728]
#  [1490.802]
#  [ 989.124]
#  [1579.752]
#  [1757.652]
#  [ 462.54 ]
#  [2134.8  ]
#  [2028.06 ]
#  [1899.972]
#  [2134.8  ]
#  [2156.148]
#  [2149.032]
#  [1515.708]
#  [1423.2  ]
#  [1814.58 ]
#  [1127.886]
#  [ 693.81 ]
#  [1263.09 ]
# ...

# %%
print("The actual value is: {}".format (y_test))
# Out:
# The actual value is: [[ 50000]
#  [ 75000]
#  [ 55000]
#  [ 65000]
#  [130000]
#  [ 98000]
#  [ 70000]
#  [110000]
#  [ 65000]
#  [200000]
#  [ 40000]
#  [ 38000]
#  [ 50000]
#  [100000]
#  [138888]
#  [150000]
#  [ 51500]
#  [ 76000]
#  [ 48120]
#  [ 20000]
#  [ 69999]
#  [ 24030]
#  [ 28000]
#  [185000]
#  [ 75000]
#  [ 67000]
#  [ 28000]
#  [ 57000]
#  [ 32500]
#  [ 85000]
#  [ 70000]
#  [ 45000]
#  [ 60000]
#  [ 43000]
#  [ 98000]
#  [ 40000]
#  [ 35000]
#  [ 45000]
#  [ 37000]
#  [ 56000]
#  [ 26000]
#  [ 38000]
#  [120000]
#  [ 50000]
#  [100000]
#  [ 60000]
#  [ 40000]
#  [ 37000]
#  [ 77999]
#  [ 28000]
#  [ 57777]
#  [ 80000]
#  [ 59888]
#  [ 45000]
#  [ 99999]
#  [ 55000]
#  [ 25000]
#  [ 43000]
#  [ 88000]
#  [ 57000]
#  [ 55000]
#  [ 75000]
#  [ 80000]
#  [ 68000]
#  [ 68000]
#  [ 90000]
#  [ 26000]
#  [ 33000]
#  [ 37000]
#  [ 69000]
#  [ 68000]
#  [ 39000]
#  [ 45000]
#  [100000]
#  [ 40000]
#  [ 36000]
#  [ 95000]
#  [160000]
#  [ 78000]
#  [180000]
#  [ 43000]
# ...

# %%
predicted_value = linearreg.predict(X_test)

# %%
df_new = pd.DataFrame({'Actual value' : y_test.flatten(), 'Predicted_value' : predicted_value.flatten()})

# %%
df_new.head()
# Out:
#    Actual value  Predicted_value
# 0         50000     55741.475617
# 1         75000     75264.472685
# 2         55000     76601.664265
# 3         65000     45846.257925
# 4        130000    126746.348515

# %%
sb.regplot(x="Actual value", y="Predicted_value", data=df_new)

# %%
sb.regplot(x="Actual value", y="Predicted_value", data=df_new, n_boot=1000, scatter=True, fit_reg=True)

# %%
from sklearn import metrics

# %%
metrics.mean_squared_error(y_test, predicted_value)
# Out:
# 388592717.75394607

# %%
import numpy as np

# %%
MSE = np.square(np.subtract(y_test,predicted_value)).mean()

# %%
print("Mean squared Error--- MSE is: {}".format (MSE))
# Out:
# Mean squared Error--- MSE is: 388592717.75394607

# %%
RMSE = np.sqrt(matrics(y_test,predicted_value)).mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-297-d79a24e1440a> in <module>
# ----> 1 RMSE = np.sqrt(matrics(y_test,predicted_value)).mean()
#
# NameError: name 'matrics' is not defined

# %%
RMSE= np.sqrt(metrics.mean_squared_error(y_test, predicted_value))

# %%
print("Root of Mean squared Error=== RMSE is: {}".format (RMSE))
# Out:
# Root of Mean squared Error=== RMSE is: 19712.755204535617

# %%
from sklearn.metrics import r2_score

# %%
R_SQUARE = r2_score(y_test, predicted_value)

# %%
print(" Difference between actual data & fitted data: R-square: {}".format (R_SQUARE))
# Out:
#  Difference between actual data & fitted data: R-square: 0.6831568293794477

# %%
sb.heatmap(df_new.corr(), annot=True, square=False)

# %%
import statsmodels.api as stat

# %%
X=df["Sqft"]
y=df["Price"]

# %%
Intercept_value = stat.add_constant(X)
# Out:
# C:\Users\LENOVO PC\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
Intercept_value
# Out:
#      const      Sqft
# 0      1.0  1177.698
# 1      1.0  2134.800
# 2      1.0  1138.560
# 3      1.0  1458.780
# 4      1.0   967.776
# ..     ...       ...
# 640    1.0  1359.156
# 641    1.0   377.148
# 642    1.0   740.064
# 643    1.0  1707.840
# 644    1.0  1376.946
#
# [639 rows x 2 columns]

# %%
stat_reg = stat.OLS(y, Intercept_value)

# %%
stat_fit = stat_reg.fit()

# %%
print(stat_fit.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.683
# Model:                            OLS   Adj. R-squared:                  0.683
# Method:                 Least Squares   F-statistic:                     1373.
# Date:                Thu, 03 Sep 2020   Prob (F-statistic):          4.32e-161
# Time:                        23:31:26   Log-Likelihood:                -7238.5
# No. Observations:                 639   AIC:                         1.448e+04
# Df Residuals:                     637   BIC:                         1.449e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3371.2041   1771.267      1.903      0.057    -107.024    6849.433
# ...

# %%
from yellowbrick.regressor import ResidualsPlot

# %%
visualizer = ResidualsPlot(linearreg, hist=False)
visualizer.fit(X_train, y_train)
visualizer.score(X_test, y_test)
visualizer.show()

# %%
linearreg.predict(y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-317-953b867b9e2d> in <module>
# ----> 1 linearreg.predict(y)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     219             Returns predicted values.
#     220         """
# --> 221         return self._decision_function(X)
#     222
#     223     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     202         check_is_fitted(self, "coef_")
#     203
# --> 204         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     205         return safe_sparse_dot(X, self.coef_.T,
#     206                                dense_output=True) + self.intercept_
#
# ...

# %%
X = df['Sqft'].values.reshape(-1,1)
y = df['Price'].values.reshape(-1,1)
linearreg.predict(y)
# Out:
# array([[2334519.1750397 ],
#        [2935841.97661255],
#        [2184188.47464648],
#        [1695613.69836854],
#        [1695613.69836854],
#        [5566629.23349378],
#        [2184188.47464648],
#        [1808361.72366345],
#        [1695613.69836854],
#        [2447267.20033461],
#        [1169456.24699229],
#        [1094366.06214588],
#        [1470117.64777872],
#        [1808361.72366345],
#        [2071440.44935157],
#        [3762660.82877522],
#        [1808361.72366345],
#        [ 943960.19640247],
#        [3386834.07779219],
#        [1244621.5971889 ],
#        [5265967.83270735],
#        [3762660.82877522],
#        [2071440.44935157],
#        [3950574.20426674],
#        [7520928.33860555],
#        [3687495.47857862],
#        [7520928.33860555],
#        [5453881.20819887],
#        [ 943960.19640247],
#        [ 907429.83620692],
#        [2447267.20033461],
#        [3198920.70230067],
#        [2071440.44935157],
#        [2146605.79954818],
# ...

# %%
sb.lmplot(x ="Actual value", y ="Predicted_value", data = df_new, order = 2, ci = None)

# %%
#Scttter data of predicted values
y_pred = linearreg.predict(X_test) 
mp.scatter(X_test, y_test, color ='b') 
mp.plot(X_test, y_pred, color ='k') 
  
mp.show()
